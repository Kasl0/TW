# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Kaslo\Desktop\GitHub\TW\src\main\java\Lab5\processing_times.csv")
display(data)
# Out:
#    iterations  no_threads  no_tasks      average     deviation
# 0         500           1         1   52525280.0  2.220615e+06
# 1         500           1        10  101428610.0  1.879349e+06
# 2         500           1    480000  194931670.0  1.745848e+07
# 3         500           8         8  669425910.0  3.879297e+07
# 4         500           8        80  457995770.0  1.956492e+07
# 5         500           8    480000  575445350.0  2.306847e+07
# 6         500          16        16  567886690.0  1.910132e+07
# 7         500          16       160  321819330.0  7.511961e+06
# 8         500          16    480000  400449070.0  2.518604e+07
